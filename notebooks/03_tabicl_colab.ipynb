# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path("/content/Repo")

if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

DATA_DIR = PROJECT_ROOT / "data"
OUTPUTS_DIR = PROJECT_ROOT / "outputs"
METRICS_DIR = OUTPUTS_DIR / "metrics"
PREDICTIONS_DIR = OUTPUTS_DIR / "predictions"

OUTPUTS_DIR.mkdir(parents=True, exist_ok=True)
METRICS_DIR.mkdir(parents=True, exist_ok=True)
PREDICTIONS_DIR.mkdir(parents=True, exist_ok=True)

print("PROJECT_ROOT =", PROJECT_ROOT)

# %%
import importlib
import src.data_utils as data_utils
import src.cv_runner as cv_runner
import src.metrics_utils as metrics_utils
import src.results_utils as results_utils

importlib.reload(data_utils)
importlib.reload(cv_runner)
importlib.reload(metrics_utils)
importlib.reload(results_utils)

# %%
# !pip install -q torch
